# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
from matplotlib.colors import BoundaryNorm

import cartopy.crs as ccrs
from som import Som, cluster

# %%
def calc_anom(da):
    climatology_mean = da.groupby("time.month").mean("time")
    climatology_std = da.groupby("time.month").std("time")
    anom = (da.groupby("time.month") - climatology_mean) / climatology_std
    return anom

# %%
print("Self-Organizing Feature Map Analysis")
# Load data
ds = xr.open_dataset("../Data/u850.nc")
uwnd850 = ds["uwnd"].sel(
    lat=slice(60.0, -10.0),
    lon=slice(100.0, 180.0),
    time=slice("1991", "2023"),
)
uwnd850 = uwnd850.sel(time=uwnd850.time.dt.month.isin([6, 7, 8]))
uwnd850_anom = calc_anom(uwnd850)
uwnd850_anom = uwnd850_anom.drop_vars(["month", "level"])
# Coordinates
lon = uwnd850_anom.lon
lat = uwnd850_anom.lat
nd = len(lon) * len(lat)
nt = uwnd850_anom.time.size

# Reshape to (nd, nt)
x = uwnd850_anom.values.reshape(nt, nd).T
# Out:
# Self-Organizing Feature Map Analysis

# %%
# SOM parameters
m1 = 3
m2 = 3
nter = 5000
alpha0 = 5.0
alphamin = 0.05
taua = 1000
sigma0 = 2.5
taus = 500

# %%
# Train SOM
w = Som(x, nd, nt, m1, m2, nter, alpha0, taua, alphamin, sigma0, taus)
# Out:
# Training SOM...
# Input data normalized
# Iteration 50, alpha=4.7609, sigma=2.2666
# Iteration 100, alpha=4.5287, sigma=2.0509
# Iteration 150, alpha=4.3078, sigma=1.8558
# Iteration 200, alpha=4.0977, sigma=1.6792
# Iteration 250, alpha=3.8979, sigma=1.5194
# Iteration 300, alpha=3.7078, sigma=1.3748
# Iteration 350, alpha=3.5270, sigma=1.2439
# Iteration 400, alpha=3.3550, sigma=1.1256
# Iteration 450, alpha=3.1913, sigma=1.0185
# Iteration 500, alpha=3.0357, sigma=0.9215
# Iteration 550, alpha=2.8876, sigma=0.8338
# Iteration 600, alpha=2.7468, sigma=0.7545
# Iteration 650, alpha=2.6128, sigma=0.6827
# Iteration 700, alpha=2.4854, sigma=0.6177
# Iteration 750, alpha=2.3642, sigma=0.5589
# Iteration 800, alpha=2.2489, sigma=0.5058
# Iteration 850, alpha=2.1392, sigma=0.5000
# Iteration 900, alpha=2.0349, sigma=0.5000
# Iteration 950, alpha=1.9356, sigma=0.5000
# Iteration 1000, alpha=1.8412, sigma=0.5000
# Iteration 1050, alpha=1.7514, sigma=0.5000
# Iteration 1100, alpha=1.6660, sigma=0.5000
# Iteration 1150, alpha=1.5848, sigma=0.5000
# Iteration 1200, alpha=1.5075, sigma=0.5000
# Iteration 1250, alpha=1.4340, sigma=0.5000
# Iteration 1300, alpha=1.3640, sigma=0.5000
# Iteration 1350, alpha=1.2975, sigma=0.5000
# Iteration 1400, alpha=1.2342, sigma=0.5000
# Iteration 1450, alpha=1.1740, sigma=0.5000
# Iteration 1500, alpha=1.1168, sigma=0.5000
# Iteration 1550, alpha=1.0623, sigma=0.5000
# Iteration 1600, alpha=1.0105, sigma=0.5000
# Iteration 1650, alpha=0.9612, sigma=0.5000
# Iteration 1700, alpha=0.9143, sigma=0.5000
# Iteration 1750, alpha=0.8697, sigma=0.5000
# Iteration 1800, alpha=0.8273, sigma=0.5000
# Iteration 1850, alpha=0.7870, sigma=0.5000
# Iteration 1900, alpha=0.7486, sigma=0.5000
# Iteration 1950, alpha=0.7121, sigma=0.5000
# Iteration 2000, alpha=0.6774, sigma=0.5000
# Iteration 2050, alpha=0.6443, sigma=0.5000
# Iteration 2100, alpha=0.6129, sigma=0.5000
# Iteration 2150, alpha=0.5830, sigma=0.5000
# Iteration 2200, alpha=0.5546, sigma=0.5000
# Iteration 2250, alpha=0.5275, sigma=0.5000
# Iteration 2300, alpha=0.5018, sigma=0.5000
# Iteration 2350, alpha=0.4773, sigma=0.5000
# Iteration 2400, alpha=0.4540, sigma=0.5000
# Iteration 2450, alpha=0.4319, sigma=0.5000
# Iteration 2500, alpha=0.4108, sigma=0.5000
# Iteration 2550, alpha=0.3908, sigma=0.5000
# Iteration 2600, alpha=0.3717, sigma=0.5000
# Iteration 2650, alpha=0.3536, sigma=0.5000
# Iteration 2700, alpha=0.3364, sigma=0.5000
# Iteration 2750, alpha=0.3200, sigma=0.5000
# Iteration 2800, alpha=0.3044, sigma=0.5000
# Iteration 2850, alpha=0.2895, sigma=0.5000
# Iteration 2900, alpha=0.2754, sigma=0.5000
# Iteration 2950, alpha=0.2620, sigma=0.5000
# Iteration 3000, alpha=0.2492, sigma=0.5000
# Iteration 3050, alpha=0.2370, sigma=0.5000
# Iteration 3100, alpha=0.2255, sigma=0.5000
# Iteration 3150, alpha=0.2145, sigma=0.5000
# Iteration 3200, alpha=0.2040, sigma=0.5000
# Iteration 3250, alpha=0.1941, sigma=0.5000
# Iteration 3300, alpha=0.1846, sigma=0.5000
# Iteration 3350, alpha=0.1756, sigma=0.5000
# Iteration 3400, alpha=0.1670, sigma=0.5000
# Iteration 3450, alpha=0.1589, sigma=0.5000
# Iteration 3500, alpha=0.1511, sigma=0.5000
# Iteration 3550, alpha=0.1438, sigma=0.5000
# Iteration 3600, alpha=0.1368, sigma=0.5000
# Iteration 3650, alpha=0.1301, sigma=0.5000
# Iteration 3700, alpha=0.1237, sigma=0.5000
# Iteration 3750, alpha=0.1177, sigma=0.5000
# Iteration 3800, alpha=0.1120, sigma=0.5000
# Iteration 3850, alpha=0.1065, sigma=0.5000
# Iteration 3900, alpha=0.1013, sigma=0.5000
# Iteration 3950, alpha=0.0964, sigma=0.5000
# Iteration 4000, alpha=0.0917, sigma=0.5000
# Iteration 4050, alpha=0.0872, sigma=0.5000
# Iteration 4100, alpha=0.0829, sigma=0.5000
# Iteration 4150, alpha=0.0789, sigma=0.5000
# Iteration 4200, alpha=0.0751, sigma=0.5000
# Iteration 4250, alpha=0.0714, sigma=0.5000
# Iteration 4300, alpha=0.0679, sigma=0.5000
# Iteration 4350, alpha=0.0646, sigma=0.5000
# Iteration 4400, alpha=0.0614, sigma=0.5000
# Iteration 4450, alpha=0.0585, sigma=0.5000
# Iteration 4500, alpha=0.0556, sigma=0.5000
# Iteration 4550, alpha=0.0529, sigma=0.5000
# Iteration 4600, alpha=0.0503, sigma=0.5000
# Iteration 4650, alpha=0.0500, sigma=0.5000
# Iteration 4700, alpha=0.0500, sigma=0.5000
# Iteration 4750, alpha=0.0500, sigma=0.5000
# Iteration 4800, alpha=0.0500, sigma=0.5000
# Iteration 4850, alpha=0.0500, sigma=0.5000
# Iteration 4900, alpha=0.0500, sigma=0.5000
# Iteration 4950, alpha=0.0500, sigma=0.5000
# Iteration 5000, alpha=0.0500, sigma=0.5000
# Final learning rate: 0.05
# Final influence radius: 0.5

# %%
# Cluster
cluster1, cluster2, qerr, qerror, count = cluster(x, w, nd, nt, m1, m2)
# Out:
# Clustering...
# Neurons (i,j) counts quantization_error:
# Neuron 1 (1, 1) = 381 (1.1018)
# Neuron 2 (2, 1) = 375 (1.1189)
# Neuron 3 (3, 1) = 318 (1.1171)
# Neuron 4 (1, 2) = 311 (1.1236)
# Neuron 5 (2, 2) = 312 (1.1291)
# Neuron 6 (3, 2) = 281 (1.1223)
# Neuron 7 (1, 3) = 343 (1.0683)
# Neuron 8 (2, 3) = 375 (1.1051)
# Neuron 9 (3, 3) = 340 (1.1230)
# Quantization Error = 1.1115

# %%
# ---------------------------
# Average maps per neuron
# ---------------------------
# Pre-allocate storage for average maps (lon x lat x neurons)
avg_maps = np.empty((len(lon), len(lat), m1 * m2), dtype=float)

# Build neuron indices for each sample (1-based like Julia)
neuron_indices = cluster1 + (cluster2 - 1) * m1  # shape (nt,)

for neuron in range(1, m1 * m2 + 1):
    inds = np.where(neuron_indices == neuron)[0]
    if inds.size == 0:
        avg_maps[:, :, neuron - 1] = np.nan
    else:
        # mean over selected time indices
        sel = uwnd850_anom.isel(time=inds).mean(dim="time", keep_attrs=False)
        sel = sel.transpose("lon", "lat")
        avg_maps[:, :, neuron - 1] = sel.values

# %%
vmin = -0.05
vmax = 0.05
boundaries = np.linspace(-0.05, 0.05, 11)
norm = BoundaryNorm(boundaries=boundaries, ncolors=256, extend="both")

fig = plt.figure(layout="constrained", figsize=(m1 * 5, m2 * 4))
axes = fig.subplots(3, 3, subplot_kw={"projection": ccrs.PlateCarree()})
for i, ax in enumerate(axes.flat):
    feature = avg_maps[:, :, i]
    im = ax.contourf(
        uwnd850_anom.lon,
        uwnd850_anom.lat,
        feature.T,
        cmap="RdBu_r",
        norm=norm,
        transform=ccrs.PlateCarree(),
    )
    ax.contour(im, colors="black", linewidths=(0.5,))
    ax.set_title(f"Cluster {i + 1}: {count[i]}", fontsize=14)
    ax.coastlines()
    gl = ax.gridlines(draw_labels=True)
    gl.top_labels = False
    gl.right_labels = False
    ax.set_extent([100, 180, -10, 60], crs=ccrs.PlateCarree())

cbar = fig.colorbar(
    ScalarMappable(norm=norm, cmap="RdBu_r"),
    ax=axes[:, :],
    location="bottom",
    fraction=0.05,
    pad=0.02,
)
cbar.set_label("U-wind 850hPa Anomaly (m/s)", fontsize=12)
plt.suptitle("U-wind 850hPa Anomaly SOM", fontsize=16)
plt.savefig("../Results/uwnd850_anom_som.png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 35
#      33 cbar.set_label("U-wind 850hPa Anomaly (m/s)", fontsize=12)
#      34 plt.suptitle("U-wind 850hPa Anomaly SOM", fontsize=16)
# ---> 35 plt.savefig("../Figures/uwnd850_anom_som.png", dpi=300)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\PIL\Image.py:2566, in Image.save(self, fp, format, **params)
#    2564         fp = builtins.open(filename, "r+b")
#    2565     else:
# -> 2566         fp = builtins.open(filename, "w+b")
#    2567 else:
#    2568     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Figures/uwnd850_anom_som.png'

# %%
# Counting
clusters = cluster1 + (cluster2 - 1) * 3

# %%
time = uwnd850_anom.time

# %%
df = pd.DataFrame(
    {"cluster": clusters},
    index=pd.to_datetime(time),
)

# %%
df["cluster"] = df["cluster"].astype("category")

# Extract year
df["year"] = df.index.to_period(freq="Y")

# Group and count
counts = df.groupby(["cluster", "year"], observed=True).size().reset_index(name="count")
counts = counts.pivot(index="year", columns="cluster", values="count").fillna(0)
counts.to_csv("../Data/u850_cluster_counts.csv")

# %%
# Plot time series
# Create one figure with 3x3 subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12), layout="constrained")
axes = axes.flatten()  # flatten to easily iterate over
t = range(1991, 2024)
for i in range(0, 9):
    ax = axes[i]
    ax.plot(t, counts[i + 1], "-o")
    ax.set_xlabel("Year")
    ax.set_ylabel("Counts")
    ax.set_ylim(-5, 50)
    ax.set_xlim(1990, 2025)
    ax.tick_params(axis="both", tickdir="in")
    ax.grid(True)
    ax.set_title(f"cluster {i + 1}: {int(counts[i + 1].sum())}")

fig.suptitle("Occurences each year")
# Save one combined figure
plt.savefig("../Results/u850a_cluster_timeseries.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 19
#      17 fig.suptitle("Occurences each year")
#      18 # Save one combined figure
# ---> 19 plt.savefig("../Figures/u850a_cluster_timeseries.png")
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\PIL\Image.py:2566, in Image.save(self, fp, format, **params)
#    2564         fp = builtins.open(filename, "r+b")
#    2565     else:
# -> 2566         fp = builtins.open(filename, "w+b")
#    2567 else:
#    2568     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Figures/u850a_cluster_timeseries.png'

# %%
# u850
ds = xr.open_dataset("../Data/u850.nc")
ds = ds.sel(time=ds.time.dt.month.isin([6, 7, 8]))
da = calc_anom(ds)
da = da.drop_vars("month")

print(da)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       3 ds = ds.sel(time=slice("1991", "2023"))
#       4 ds = ds.sel(time=ds.time.dt.month.isin([6, 7, 8]))
# ----> 5 da = calc_anom(ds)
#       6 da = da.drop_vars("month")
#       8 print(da)
#
# Cell In[17], line 3, in calc_anom(da)
#       1 def calc_anom(da):
#       2     climatology_mean = da.groupby("time.month").mean("time")
# ----> 3     climatology_std = da.groupby("time.month").std("time")
#       4     anom = (da.groupby("time.month") - climatology_mean) / climatology_std
#       5     return anom
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\_aggregations.py:4680, in DatasetGroupByAggregations.std(self, dim, skipna, ddof, keep_attrs, **kwargs)
#    4669     return self._flox_reduce(
#    4670         func="std",
#    4671         dim=dim,
#    (...)   4677         **kwargs,
#    4678     )
#    4679 else:
# -> 4680     return self.reduce(
#    4681         duck_array_ops.std,
#    4682         dim=dim,
#    4683         skipna=skipna,
#    4684         ddof=ddof,
#    4685         numeric_only=True,
#    4686         keep_attrs=keep_attrs,
#    4687         **kwargs,
#    4688     )
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\groupby.py:1884, in DatasetGroupByBase.reduce(self, func, dim, axis, keep_attrs, keepdims, shortcut, **kwargs)
#    1873     return ds.reduce(
#    1874         func=func,
#    1875         dim=dim,
#    (...)   1879         **kwargs,
#    1880     )
#    1882 check_reduce_dims(dim, self.dims)
# -> 1884 return self.map(reduce_dataset)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\groupby.py:1780, in DatasetGroupByBase.map(self, func, args, shortcut, **kwargs)
#    1778 # ignore shortcut if set (for now)
#    1779 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
# -> 1780 return self._combine(applied)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\groupby.py:1800, in DatasetGroupByBase._combine(self, applied)
#    1798 def _combine(self, applied):
#    1799     """Recombine the applied objects like the original."""
# -> 1800     applied_example, applied = peek_at(applied)
#    1801     dim, positions = self._infer_concat_args(applied_example)
#    1802     combined = concat(
#    1803         applied,
#    1804         dim,
#    (...)   1808         join="outer",
#    1809     )
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\utils.py:287, in peek_at(iterable)
#     283 """Returns the first value from iterable, as well as a new iterator with
#     284 the same content as the original iterable
#     285 """
#     286 gen = iter(iterable)
# --> 287 peek = next(gen)
#     288 return peek, itertools.chain([peek], gen)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\groupby.py:1779, in <genexpr>(.0)
#    1749 """Apply a function to each Dataset in the group and concatenate them
#    1750 together into a new Dataset.
#    1751
#    (...)   1776     The result of splitting, applying and combining this dataset.
#    1777 """
#    1778 # ignore shortcut if set (for now)
# -> 1779 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
#    1780 return self._combine(applied)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\groupby.py:1873, in DatasetGroupByBase.reduce.<locals>.reduce_dataset(ds)
#    1872 def reduce_dataset(ds: Dataset) -> Dataset:
# -> 1873     return ds.reduce(
#    1874         func=func,
#    1875         dim=dim,
#    1876         axis=axis,
#    1877         keep_attrs=keep_attrs,
#    1878         keepdims=keepdims,
#    1879         **kwargs,
#    1880     )
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\dataset.py:6881, in Dataset.reduce(self, func, dim, keep_attrs, keepdims, numeric_only, **kwargs)
#    6862     elif (
#    6863         # Some reduction functions (e.g. std, var) need to run on variables
#    6864         # that don't have the reduce dims: PR5393
#    (...)   6874         # the former is often more efficient
#    6875         # keep single-element dims as list, to support Hashables
#    6876         reduce_maybe_single = (
#    6877             None
#    6878             if len(reduce_dims) == var.ndim and var.ndim != 1
#    6879             else reduce_dims
#    6880         )
# -> 6881         variables[name] = var.reduce(
#    6882             func,
#    6883             dim=reduce_maybe_single,
#    6884             keep_attrs=keep_attrs,
#    6885             keepdims=keepdims,
#    6886             **kwargs,
#    6887         )
#    6889 coord_names = {k for k in self.coords if k in variables}
#    6890 indexes = {k: v for k, v in self._indexes.items() if k in variables}
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\variable.py:1767, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1760 keep_attrs_ = (
#    1761     _get_keep_attrs(default=True) if keep_attrs is None else keep_attrs
#    1762 )
#    1764 # Note that the call order for Variable.mean is
#    1765 #    Variable.mean -> NamedArray.mean -> Variable.reduce
#    1766 #    -> NamedArray.reduce
# -> 1767 result = super().reduce(
#    1768     func=func, dim=dim, axis=axis, keepdims=keepdims, **kwargs
#    1769 )
#    1771 # return Variable always to support IndexVariable
#    1772 return Variable(
#    1773     result.dims, result._data, attrs=result._attrs if keep_attrs_ else None
#    1774 )
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\namedarray\core.py:917, in NamedArray.reduce(self, func, dim, axis, keepdims, **kwargs)
#     913     if isinstance(axis, tuple) and len(axis) == 1:
#     914         # unpack axis for the benefit of functions
#     915         # like np.argmin which can't handle tuple arguments
#     916         axis = axis[0]
# --> 917     data = func(self.data, axis=axis, **kwargs)
#     918 else:
#     919     data = func(self.data, **kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\xarray\core\duck_array_ops.py:532, in _create_nan_agg_method.<locals>.f(values, axis, skipna, **kwargs)
#     530     with warnings.catch_warnings():
#     531         warnings.filterwarnings("ignore", "All-NaN slice encountered")
# --> 532         return func(values, axis=axis, **kwargs)
#     533 except AttributeError:
#     534     if not is_duck_dask_array(values):
#
# File ~\miniforge3\envs\py311\Lib\site-packages\numpy\_core\fromnumeric.py:4028, in std(a, axis, dtype, out, ddof, keepdims, where, mean, correction)
#    4025     else:
#    4026         return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# -> 4028 return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    4029                      **kwargs)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\numpy\_core\_methods.py:219, in _std(a, axis, dtype, out, ddof, keepdims, where, mean)
#     217 def _std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False, *,
#     218          where=True, mean=None):
# --> 219     ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#     220                keepdims=keepdims, where=where, mean=mean)
#     222     if isinstance(ret, mu.ndarray):
#     223         ret = um.sqrt(ret, out=ret)
#
# File ~\miniforge3\envs\py311\Lib\site-packages\numpy\_core\_methods.py:168, in _var(a, axis, dtype, out, ddof, keepdims, where, mean)
#     163     arrmean = mean
#     164 else:
#     165     # Compute the mean.
#     166     # Note that if dtype is not of inexact type then arraymean will
#     167     # not be either.
# --> 168     arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
#     169     # The shape of rcount has to match arrmean to not change the shape of
#     170     # out in broadcasting. Otherwise, it cannot be stored back to arrmean.
#     171     if rcount.ndim == 0:
#     172         # fast-path for default case when where is True
#
# UFuncTypeError: ufunc 'add' cannot use operands with types dtype('<M8[ns]') and dtype('<M8[ns]')

# %%
# ---------------------------
# Composite for SST_JJA
# ---------------------------
import numpy as np

# Ensure data is filtered to JJA and aligned with SOM samples
da_comp = sst_jja
if 'month' in da_comp.coords:
    da_comp = da_comp.drop_vars('month')
# The SOM training was done on JJA data. Ensure this data matches in length.
da_comp_jja = da_comp.sel(time=da_comp.time.dt.month.isin([6, 7, 8]))

# Building neuron labels (1-based) from SOM output
# m1, cluster1, cluster2 come from the SOM training section
neuron_labels = cluster1 + (cluster2 - 1) * m1

# Calculate average maps per neuron
# We use the dimensions of the composite data
avg_maps_comp = np.empty((len(da_comp_jja.lon), len(da_comp_jja.lat), m1 * m2), dtype=float)

for neuron in range(1, m1 * m2 + 1):
    inds = np.where(neuron_labels == neuron)[0]
    if inds.size == 0:
        avg_maps_comp[:, :, neuron - 1] = np.nan
    else:
        # Mean over selected time indices
        sel_mean = da_comp_jja.isel(time=inds).mean(dim="time", keep_attrs=False)
        # Transpose to (lon, lat) to match the plotting expectation in some cells
        if 'lon' in sel_mean.dims and 'lat' in sel_mean.dims:
            sel_mean = sel_mean.transpose("lon", "lat")
        avg_maps_comp[:, :, neuron - 1] = sel_mean.values

# Replace the original avg_maps (or whatever the plotting block uses)
avg_maps = avg_maps_comp
